# %% [markdown]
# # Python E-101
# ## Homework 2
#
# Assigned: 2021-4-17
#
# Due: 2021-4-21 (before class)
#
# email your solution to me at cmorace.public@gmail.com
#
# ---

# %% [markdown]
# Exercise 1:
#
# Given a list of names print out hello to each person. For example if the list is `["Ruby", "David", "Charles"]`your program should print out
# ```
# hello Ruby
# hello David
# hello Charles
# ```

# %%
x = ["Ruby", "David", "Charles"]

# %% [markdown]
# ---

# %% [markdown]
# Exercise 2:
#
# Given two lists, find the sum of all elements in each list and print the list with the larger sum. For example, if
# ```
# x = [1, -1, 0, 12, -5]
# y = [4, 3, -2, 9, 4, -5]
# ```
# your program should print out `[4, 3, -2, 9, 4, -5]` since `sum(x)` is `7` and `sum(y)` is `13`

# %%
x = [1, -1, 0, 12, -5]
y = [4, 3, -2, 9, 4, -5]

# %% [markdown]
# ---

# %% [markdown]
# Exercise 3:
#
# Given a list, swap the first and last elements and print the result. For example, if `x=[1, 2, 3, 4, 5]`, your program should print out `[5, 2, 3, 4, 1]`
# ```

# %%
x=[1, 2, 3, 4, 5]

# %% [markdown]
# ---

# %% [markdown]
# Bonus Question:
#
# Given two lists of the same length return the 'dot product' of the two lists. For example if `x=[1,2,3]` and `y=[4,5,6]`, your program should print out `32` since `1*4 + 2*5 + 3*6 = 32`
