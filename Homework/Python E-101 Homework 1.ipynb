# %% [markdown]
# # Python E-101
# ## Homework 1
#
# Assigned: 2021-3-27
#
# Due: 2021-4-3 (before class)
#
# email your solution to me at cmorace.public@gmail.com
#
# ---

# %% [markdown]
# Exercise 1:
#
# Use the `input` function to get a name from the user and then print out 'hello' to the user. For example if the user enters 'Sarah', your code should print out 'hello Sarah'

# %% [markdown]
# ---

# %% [markdown]
# Exercise 2:
#
# Use the `input` function to get a user's age then print out 'you are an adult' if the age is greater than or equal to 18 or 'you are a child' if the age is less than 18.

# %% [markdown]
# ---

# %% [markdown]
# Exercise 3:
#
# Use `input` to get two numbers from a user, then print out the sum of the two numbers. Your code should work for floating point numbers. For example if the user enters `3.14` and `2.718`, it should print out `5.858`

# %% [markdown]
# ---

# %% [markdown]
# Bonus Question:
#
# Extend exercise 3 to include other arithmetic operators so that the user enters a first number, an operator, and a second number. For example, if the user inputs `5`, `/`, and `10`, your code should print out `0.5`. A list of all of python's arithmetic operators can be found [here](https://www.w3schools.com/python/gloss_python_arithmetic_operators.asp).
